# %%
import pandas as pd
import random
import numpy as np

# Paste your farm names here
names = [
    "Naija Harvest Group 17",
    "D'AgroHaven Nigeria Ltd",
    "Eko AgriPlus Farms Ltd",
    "Iyanu Foods Farm Ltd",
    "AquaNaija Farms Ltd",
    "Olugreen Harvest Ltd",
    "Arewa SunFarms Ltd",
    "NaijaVita Agro Farms Ltd",
    "AfriEco Growers Ltd",
    "SmartFarm Naija Ltd",
    "Oba Agritech Ltd",
    "Akaraye Roots Farms Ltd",
    "GbemiGreen Produce Ltd",
    "AgriThread Nigeria Ltd",
    "LumiAgro Waters Ltd",
    "SustainaNaija Agri Ltd",
    "Ezinne Bloom Farms Ltd",
    "NaijaBerry Agro Ltd",
    "HavenVille Greenfields Ltd",
    "Alafia Garden Greens Ltd",
    "AgroMills Naija Ltd",
    "OjaGrow Ltd",
    "Alayo Aqua Labs Ltd",
    "Aanu Farms & Fields",
    "EverNaija Greens",
    "Efo Plus Agro Ventures",
    "Itana AgriFields",
    "GreenSeven Farms Nigeria",
    "Fiatom AgriHub",
    "Farmwise HinterHub",
    "AquaNaija Grow Ltd",
    "Meya Harvest Nigeria",
    "HighYield Naija Farms",
    "OrunGreen Farms Ltd",
    "NaijaPonics Solutions Ltd",
    "AgriPrime Circle Ltd",
    "SweetSixteen Greens",
    "RootZone 14 Ltd",
    "FreshNaija Ville Ltd",
    "FELAG Farms Nigeria",
    "Alayo Verdant Fields",
    "GrooveHarvest Nigeria",
    "ProAgro Naija Ltd",
    "Eko Premium Agro Ltd",
    "Oasis Green Nigeria",
    "GrowHut Naija Ltd",
    "EcoTune Agro Ventures",
    "Naija Agro Consults",
    "TrybeAgroTech Nigeria",
    "MultiRoot Naija Ltd",
    "FeddieFields Nigeria",
    "Naija Green Group 18",
    "Naija Green Group 15",
    "Naija Green Group 16",
    "Naija Green Group 10",
    "Naija Green Group 9",
    "Naija Green Group 8",
    "Naija Green Group 7",
    "Naija Green Group 1",
    "Naija Green Group 2",
    "Naija Green Group 3",
    "Naija Farmstead Treats Ltd",
    "IfePommel Agro Ltd",
    "AgriSoft Naija Ltd",
    "IbileGreen Thumb Ltd",
    "Obalende Cavalier Farms Ltd",
    "Naija Square Greens Ltd",
    "TremNaija Fields Ltd",
    "TerraNaija Agro Ltd",
    "NaijaAgro Speed Ltd",
    "Brimsby AgriTech Naija Ltd",
    "Olamide Haven Farms Ltd",
    "EniAgro Innovate Ltd",
    "EraNaija Agro Farms",
    "PlusOne Farms Nigeria Ltd",
    "Serene Naija Sprouts Ltd",
    "Sunset AgriConsults Ltd",
    "Naija Green Group 20",
    "Naija Green Group 19",
    "Naija Green Group 14",
    "Naija Green Group 13",
    "Naija Green Group 11",
    "Naija Green Group 12",
    "Naija Green Group 6",
    "Naija Green Group 5",
    "Naija Green Group 4",
    "Sọ́nà GoldGrain Nigeria Ltd",
    "Ayotunde Greenfields Ltd",
    "AlphaVilla Agro Ltd",
    "ỌmọNaija GreenFarm Ltd",
    "V-Prime AgroSpace Nigeria Ltd",
    "Agbẹtopia Farms Ltd",
    "IleTerra Farms Ltd",
    "Oleri Garden Farms Ltd",
    "Ọrẹ Veggies Farms Ltd",
    "GLeaf Agro Nigeria Ltd",
    "Hogan HydroGro Farms Ltd",
    "Alafia Blossom Valley Farms",
    "Ata Naija Farms Ltd",
    "NaijaFarmPro Ltd",
    "Orisun Valley GreenFarms Ltd",
    "AgbẹCore Nigeria Ltd",
    "Ọlábíyí AgroSmart Veggies Ltd",
    "Furaha Veggies Naija Ltd"
]

# Assign uneven weights (you can customize this further)
# Let's assign:
# - Top 5 names → 10% each
# - Next 10 names → 3% each
# - Next 15 names → 2% each
# - The rest → equally split the remaining %

total = 1000000

weights = []
for i in range(len(names)):
    if i < 5:
        weights.append(10)  # 10% weight total for top 5
    elif i < 15:
        weights.append(3)   # 3% for next 10
    elif i < 30:
        weights.append(2)   # 2% for next 15
    else:
        weights.append(1)   # 1% for the remaining

# Normalize weights so their sum is 1 (probabilities)
probabilities = [w / sum(weights) for w in weights]

# Sample 1,000,000 names using the given probabilities
sampled_names = random.choices(names, weights=probabilities, k=total)

# Create DataFrame
df = pd.DataFrame(sampled_names, columns=["Farm Name"])

# Optional: Save to CSV
df.to_csv("uneven_farm_names.csv", index=False)

print("✅ 1,000,000 records generated with uneven distribution.")
# Out:
# ✅ 1,000,000 records generated with uneven distribution.
